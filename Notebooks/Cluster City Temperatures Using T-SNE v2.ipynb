# %% [markdown]
# # European Cities Temperature Clustering with the T-SNE algorithm

# %% [markdown]
# ## Dataset: Average Monthly Temperatures for Several Cities around Europe
# ### Sourced: http://factominer.free.fr/course/MOOC.html

# %% [markdown]
# ### Motivation: The above resource by F. Husson shows that using simple PCA  analysis will discrimate cities by average temperature PC1 and by amplitude (hottest temp- coldest temp) PC2 (which is obvious when you think about it).
# ### A more sophisticated algorithm may  a) find less obvious patterns and b)better disciminate amplitude so as to help with clustering.

# %% [markdown]
# ## Version 2: Feature engineer change in temperatures from the mean.

# %%
## Required output: 
## - Cluster number for each city
## - Line chart visualizations each city in facet chart.

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
from sklearn.manifold import TSNE

# %%
# Potentially Useful variables

# A list of months
lstMonths = ['January', 'February', 'March', 'April', 'May', 'June', 
             'July', 'August','September' , 'October', 'November', 'December'] 

# A lookup from month name to number 
df_month_lookup = pd.DataFrame ( {'Month':  lstMonths } )
df_month_lookup['MonthNo'] = df_month_lookup.index + 1
df_month_lookup = df_month_lookup.set_index ('Month')
df_month_lookup['MonthNo'].astype (str)
# Out:
# Month
# January       1
# February      2
# March         3
# April         4
# May           5
# June          6
# July          7
# August        8
# September     9
# October      10
# November     11
# December     12
# Name: MonthNo, dtype: object

# %%
# Read in Data
df = pd.read_csv ( 'http://factominer.free.fr/course/donnees/data_clustering_Temperature.csv', sep=';')
df.head ()
# Out:
#    Unnamed: 0  January  February  March  April   May  June  July  August  \
# 0  Amsterdam       2.9       2.5    5.7    8.2  12.5  14.8  17.1    17.1
# 1     Athens       9.1       9.7   11.7   15.4  20.1  24.5  27.4    27.2
# 2     Berlin      -0.2       0.1    4.4    8.2  13.8  16.0  18.3    18.0
# 3    Brussels      3.3       3.3    6.7    8.9  12.8  15.6  17.8    17.8
# 4   Budapest      -1.1       0.8    5.5   11.6  17.0  20.2  22.0    21.3
#
#    September  October  November  December  Annual  Amplitude  Latitude  \
# 0       14.5     11.4       7.0       4.4     9.9       14.6      52.2
# 1       23.8     19.2      14.6      11.0    17.8       18.3      37.6
# 2       14.4     10.0       4.2       1.2     9.1       18.5      52.3
# 3       15.0     11.1       6.7       4.4    10.3       14.4      50.5
# 4       16.9     11.3       5.1       0.7    10.9       23.1      47.3
#
#    Longitude   Area
# 0        4.5   West
# 1       23.5  South
# 2       13.2   West
# 3        4.2   West
# 4       19.0   East

# %%
# Obtain some data to process..
df.columns = np.insert ( df.columns[1:], 0,'Country' ,axis=0)
df_train = df.drop(df.columns[[13,14,15,16,17]], axis=1, inplace=False)
df_train.head ()
# Out:
#       Country  January  February  March  April   May  June  July  August  \
# 0  Amsterdam       2.9       2.5    5.7    8.2  12.5  14.8  17.1    17.1
# 1     Athens       9.1       9.7   11.7   15.4  20.1  24.5  27.4    27.2
# 2     Berlin      -0.2       0.1    4.4    8.2  13.8  16.0  18.3    18.0
# 3    Brussels      3.3       3.3    6.7    8.9  12.8  15.6  17.8    17.8
# 4   Budapest      -1.1       0.8    5.5   11.6  17.0  20.2  22.0    21.3
#
#    September  October  November  December
# 0       14.5     11.4       7.0       4.4
# 1       23.8     19.2      14.6      11.0
# 2       14.4     10.0       4.2       1.2
# 3       15.0     11.1       6.7       4.4
# 4       16.9     11.3       5.1       0.7

# %%
# V2 Feature engineering step, Create new columns representing difference from the overall copuntry mean for each city
monthlyMeansArray = df [ lstMonths ].mean (axis = 0)  # averages for January, February ... December across cities

#df [ lstMonths ].mean (axis = 1) # this would do annual average for a city which we already have ( annual column)
dfMonthlyDifFromMeans = df_train [ lstMonths ]  / monthlyMeansArray

# Need to change the column names from e.g. 'January' to 'JanuaryMD'...  mean deviation
dfMonthlyDifFromMeans.columns = [i + 'MD' for i in dfMonthlyDifFromMeans]

# Slot the new columns to df_train
df_train = pd.concat ( [df_train, dfMonthlyDifFromMeans], axis=1)

# %%
# Run the TNE algorithm
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2, perplexity = 15).fit_transform( df_train.iloc [ : , 1:] ) # Exclude Country

# %%
# Merge together
df_out = pd.concat ( [df, pd.DataFrame ( X_embedded, columns =['d1','d2'] )], axis=1 )
df_out.head()
# Out:
#       Country  January  February  March  April   May  June  July  August  \
# 0  Amsterdam       2.9       2.5    5.7    8.2  12.5  14.8  17.1    17.1
# 1     Athens       9.1       9.7   11.7   15.4  20.1  24.5  27.4    27.2
# 2     Berlin      -0.2       0.1    4.4    8.2  13.8  16.0  18.3    18.0
# 3    Brussels      3.3       3.3    6.7    8.9  12.8  15.6  17.8    17.8
# 4   Budapest      -1.1       0.8    5.5   11.6  17.0  20.2  22.0    21.3
#
#    September  October  November  December  Annual  Amplitude  Latitude  \
# 0       14.5     11.4       7.0       4.4     9.9       14.6      52.2
# 1       23.8     19.2      14.6      11.0    17.8       18.3      37.6
# 2       14.4     10.0       4.2       1.2     9.1       18.5      52.3
# 3       15.0     11.1       6.7       4.4    10.3       14.4      50.5
# 4       16.9     11.3       5.1       0.7    10.9       23.1      47.3
#
#    Longitude   Area         d1          d2
# 0        4.5   West   5.873405  -10.509941
# 1       23.5  South -76.856049 -109.792778
# 2       13.2   West  -7.985556   46.751625
# 3        4.2   West -23.921516  -14.746290
# 4       19.0   East  43.669281   36.346111

# %%
 
sns.set_context ('notebook', font_scale =1.1)
sns.set_style = ('ticks')
sns.scatterplot ( x = 'd1', y='d2', data = df_out, hue='Amplitude')

# %%
sns.set_context ('notebook', font_scale =1.1)
sns.set_style = ('ticks')
sns.scatterplot ( x = 'd1', y='d2', data = df_out, hue='Area')

# %%
sns.set_context ('notebook', font_scale =1.1)
sns.set_style = ('ticks')
sns.scatterplot ( x = 'd1', y='d2', data = df_out, hue='Annual')

# %%
# Apply k means
import pandas as pd
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=9)
df_out['cluster'] =   kmeans.fit_predict(  df_out [['d1', 'd2']])

# %%
sns.set_context ('notebook', font_scale =1.1)
sns.set_style = ('ticks')
sns.scatterplot ( x = 'd1', y='d2', data = df_out, hue='cluster')

# %%
#pd.crosstab(df_out, ['cluster', 'Area'] )     
df_out.groupby(['cluster', 'Area'])['cluster'].count().unstack().fillna(0)
# Out:
# Area     East  North  South  West
# cluster
# 0         1.0    1.0    1.0   3.0
# 1         0.0    0.0    7.0   0.0
# 2         0.0    3.0    0.0   1.0
# 3         3.0    1.0    0.0   0.0
# 4         0.0    0.0    0.0   3.0
# 5         0.0    2.0    0.0   0.0
# 6         2.0    1.0    0.0   0.0
# 7         0.0    0.0    2.0   1.0
# 8         2.0    0.0    0.0   1.0

# %%
# Create a column cluster_reorder which labels ascending by Annual average Temparture
df_ordering =  pd.pivot_table(df_out,index=["cluster"],values=["Annual", "Amplitude"],aggfunc=np.mean).sort_values (['Annual', 'Amplitude'])
df_ordering ['cluster_reorder'] = df_ordering.reset_index().index

df_out['OrigIndex'] = df_out.index
df_out  = df_out.set_index ('cluster').join ( df_ordering  [['cluster_reorder']]).set_index (['OrigIndex']).sort_index()

df_out.head (100)
# Out:
#                    Country  January  February  March  April   May  June  July  \
# OrigIndex
# 0               Amsterdam       2.9       2.5    5.7    8.2  12.5  14.8  17.1
# 1                  Athens       9.1       9.7   11.7   15.4  20.1  24.5  27.4
# 2                  Berlin      -0.2       0.1    4.4    8.2  13.8  16.0  18.3
# 3                 Brussels      3.3       3.3    6.7    8.9  12.8  15.6  17.8
# 4                Budapest      -1.1       0.8    5.5   11.6  17.0  20.2  22.0
# 5              Copenhagen      -0.4      -0.4    1.3    5.8  11.1  15.4  17.1
# 6                  Dublin       4.8       5.0    5.9    7.8  10.4  13.3  15.0
# 7                  Elsinki     -5.8      -6.2   -2.7    3.1  10.2  14.0  17.2
# 8                    Kiev      -5.9      -5.0   -0.3    7.4  14.3  17.8  19.4
# 9                  Krakow      -3.7      -2.0    1.9    7.9  13.2  16.9  18.4
# 10                 Lisbon      10.5      11.3   12.8   14.5  16.7  19.4  21.5
# 11                 London       3.4       4.2    5.5    8.3  11.9  15.1  16.9
# 12                 Madrid       5.0       6.6    9.4   12.2  16.0  20.8  24.7
# 13                  Minsk      -6.9      -6.2   -1.9    5.4  12.4  15.9  17.4
# 14                  Moscow     -9.3      -7.6   -2.0    6.0  13.0  16.6  18.3
# 15                   Oslo      -4.3      -3.8   -0.6    4.4  10.3  14.9  16.9
# 16                  Paris       3.7       3.7    7.3    9.7  13.7  16.5  19.0
# 17                 Prague      -1.3       0.2    3.6    8.8  14.3  17.6  19.3
# 18              Reykjavik      -0.3       0.1    0.8    2.9   6.5   9.3  11.1
# 19                   Rome       7.1       8.2   10.5   13.7  17.8  21.7  24.4
# 20               Sarajevo      -1.4       0.8    4.9    9.3  13.8  17.0  18.9
# 21                  Sofia      -1.7       0.2    4.3    9.7  14.3  17.7  20.0
# 22              Stockholm      -3.5      -3.5   -1.3    3.5   9.2  14.6  17.2
# 23                Antwerp       3.1       2.9    6.2    8.9  12.9  15.5  17.9
# 24              Barcelona       9.1      10.3   11.8   14.1  17.4  21.2  24.2
# 25               Bordeaux       5.6       6.7    9.0   11.9  15.0  18.3  20.4
# 26              Edinburgh       2.9       3.6    4.7    7.1   9.9  13.0  14.7
# 27              Frankfurt       0.2       1.8    5.4    9.7  14.3  17.5  19.0
# 28                 Geneva       0.1       1.9    5.1    9.4  13.8  17.3  19.4
# 29                  Genoa       8.7       8.7   11.4   13.8  17.5  21.0  24.5
# 30                  Milan       1.1       3.6    8.0   12.6  17.3  21.3  23.8
# 31                Palermo      10.5      11.5   13.3   16.9  20.9  23.8  24.5
# 32                Seville      10.7      11.8   14.1   16.1  19.7  23.4  26.7
# 33         St. Petersburg      -8.2      -7.9   -3.7    3.2  10.0  15.4  18.4
# 34                 Zurich      -0.7       0.7    4.3    8.5  12.9  16.2  18.0
#
#            August  September  ...  November  December  Annual  Amplitude  \
# OrigIndex                     ...
# 0            17.1       14.5  ...       7.0       4.4     9.9       14.6
# 1            27.2       23.8  ...      14.6      11.0    17.8       18.3
# 2            18.0       14.4  ...       4.2       1.2     9.1       18.5
# 3            17.8       15.0  ...       6.7       4.4    10.3       14.4
# 4            21.3       16.9  ...       5.1       0.7    10.9       23.1
# 5            16.6       13.3  ...       4.1       1.3     7.8       17.5
# 6            14.6       12.7  ...       6.7       5.4     9.3       10.2
# 7            14.9        9.7  ...       0.1      -2.3     4.8       23.4
# 8            18.5       13.7  ...       1.2      -3.6     7.1       25.3
# 9            17.6       13.7  ...       2.6      -1.7     7.7       22.1
# 10           21.9       20.4  ...      13.7      11.1    15.9       11.4
# 11           16.5       14.0  ...       6.3       4.4     9.7       13.5
# 12           24.3       19.8  ...       8.7       5.4    13.9       19.7
# 13           16.3       11.6  ...       0.1      -4.2     5.5       24.3
# 14           16.7       11.2  ...      -1.1      -6.0     5.1       27.6
# 15           15.4       11.1  ...       0.5      -2.9     5.6       21.2
# 16           18.7       16.1  ...       7.3       5.2    11.2       15.3
# 17           18.7       14.9  ...       3.8       0.3     9.2       20.6
# 18           10.6        7.9  ...       1.7       0.2     4.6       11.4
# 19           24.1       20.9  ...      11.7       8.3    15.4       17.3
# 20           18.7       15.2  ...       5.1       0.8     9.4       20.3
# 21           19.5       15.8  ...       5.0       0.6     9.6       21.7
# 22           16.0       11.7  ...       1.7      -1.6     5.8       20.7
# 23           17.6       14.7  ...       6.8       4.7    10.3       15.0
# 24           24.1       21.7  ...      13.1      10.0    16.2       15.1
# 25           20.0       17.6  ...       8.5       6.1    12.7       14.8
# 26           14.3       12.1  ...       5.3       3.7     8.3       11.8
# 27           18.3       14.8  ...       4.9       1.7     9.8       18.8
# 28           18.5       15.0  ...       4.9       1.4     9.7       19.3
# 29           24.6       21.8  ...      12.2      10.0    16.1       15.9
# 30           22.8       18.9  ...       6.9       2.6    12.6       22.7
# 31           22.3       22.3  ...      14.9      12.0    16.6       14.0
# 32           26.7       24.3  ...      14.5      11.2    18.2       16.0
# 33           16.9       11.5  ...      -0.4      -5.3     4.5       26.6
# 34           17.2       14.1  ...       3.9       0.3     8.7       18.7
#
#            Latitude  Longitude   Area          d1          d2  cluster_reorder
# OrigIndex
# 0              52.2        4.5   West    5.873405  -10.509941                4
# 1              37.6       23.5  South  -76.856049 -109.792778                8
# 2              52.3       13.2   West   -7.985556   46.751625                3
# 3              50.5        4.2   West  -23.921516  -14.746290                6
# 4              47.3       19.0   East   43.669281   36.346111                5
# 5              55.4       12.3  North  -43.936096   86.260521                3
# 6              53.2        6.1  North   38.096298   -9.963581                4
# 7              60.1       25.0  North    6.007206  176.521454                0
# 8              50.3       30.3   East  -39.847443  138.784927                2
# 9              50.0       19.6   East  -16.335108  108.546944                2
# 10             38.4        9.1  South  -74.977661 -141.250107                8
# 11             51.4        0.0  North   23.576584  -37.679783                4
# 12             40.2        3.4  South  -31.709597 -103.364113                7
# 13             53.5       27.3   East  -21.915672  163.621506                0
# 14             55.7       37.6   East  -48.803600  175.196564                0
# 15             59.5       10.5  North   -3.819600  141.359772                2
# 16             48.5        2.2   West  -32.485500  -43.105797                6
# 17             50.0       14.2   East  -21.335167   68.630753                3
# 18             64.1       21.6  North   47.152267  124.851463                1
# 19             41.5       12.3  South  -49.710964 -126.612526                8
# 20             43.5       18.3  South  -39.194466   44.547707                3
# 21             42.4       23.2   East   19.968828   55.240078                5
# 22             59.2       18.0  North   20.976601  149.693314                1
# 23             51.1        4.2   West   -4.250144  -37.002125                6
# 24             41.2        2.2  South -101.203804 -123.321022                8
# 25             44.5        0.3   West  -42.897873  -74.662384                7
# 26             55.0        3.0  North   56.597137  -30.505430                4
# 27             50.1        8.4   West    7.895759   23.725269                5
# 28             46.1        6.1   West  -21.835754   20.734337                3
# 29             44.3        9.4  South -101.565361 -151.682632                8
# 30             45.3        9.2  South   -3.145663  -85.514221                7
# 31             38.1       13.1  South  -50.530483 -159.662796                8
# 32             37.2        5.6  South  -78.209373 -172.477051                8
# 33             59.6       30.2   East  -21.493547  193.565186                0
# 34             47.2        8.3   West    3.927649   78.912659                3
#
# [35 rows x 21 columns]

# %%
#df_out = df_out.sort_values (['OrigIndex'])

# Turn the wide table into a long one so that the data can be plotted.

#df_out['OrigIndex'] = df_out.index
#df_unpivoted = df_out.melt(id_vars=[ 'cluster', 'Area', 'Country']
#                          , value_vars = lstMonths
#                          , var_name ='Month'
#                          , value_name='degrees') 

df_unpivoted = df_out.melt(id_vars=['cluster_reorder', 'Area', 'Country', 'Annual'] ,
                          value_vars = lstMonths,
                           var_name ='Month',
                           value_name='degrees') 

df_unpivoted['OrigIndex'] =df_unpivoted.index
df_unpivoted = df_unpivoted.set_index ('Month').join (df_month_lookup ) 
df_unpivoted = df_unpivoted.sort_values (['MonthNo', 'Country']) 
df_unpivoted= df_unpivoted.sort_values (['MonthNo']) 
df_unpivoted = df_unpivoted.set_index ( 'OrigIndex')

#df_unpivoted['MonthNo'] = df_unpivoted['MonthNo'].astype(int)
#df_unpivoted['cluster_reorder'] = df_unpivoted['cluster_reorder'].astype(int)
#df_unpivoted = df_unpivoted.sort_values( [   'Country','MonthNo'] )

#df_unpivoted  = df_unpivoted.sort_values ( [ 'OrigIndex','Country' ])
df_unpivoted.head(200)
#df_unpivoted[
# Out:
#            cluster_reorder   Area     Country  Annual  degrees  MonthNo
# OrigIndex
# 0                        4   West  Amsterdam      9.9      2.9        1
# 30                       7  South      Milan     12.6      1.1        1
# 13                       0   East      Minsk      5.5     -6.9        1
# 14                       0   East      Moscow     5.1     -9.3        1
# 15                       2  North       Oslo      5.6     -4.3        1
# ...                    ...    ...         ...     ...      ...      ...
# 198                      6   West    Antwerp     10.3     15.5        6
# 176                      8  South     Athens     17.8     24.5        6
# 199                      8  South  Barcelona     16.2     21.2        6
# 177                      3   West     Berlin      9.1     16.0        6
# 200                      7   West   Bordeaux     12.7     18.3        6
#
# [200 rows x 6 columns]

# %%
import matplotlib.pyplot as plt 

# Create a grid : initialize it
g = sns.FacetGrid(df_unpivoted, col='cluster_reorder', hue='Country', col_wrap=3)

g = g.map(plt.plot, 'MonthNo', 'Annual')
g = g.map(plt.plot, 'MonthNo', 'degrees')

# Add a title for the whole plot
plt.subplots_adjust(top=0.92)

axes = g.axes.flatten()
for ax in axes:
    ax.axvline(7, ls='--', linewidth=2, color='grey')

plt.show()
